# %%
#Distributions and Modules
import torch.nn as nn
import torch
import torch.nn.functional as F
from torch import distributions
import pandas as pd
import numpy as np
from torch import optim
import matplotlib.pyplot as plt
import random, math
import copy
import keras
from keras.models import Sequential
from keras.layers import *
from keras.optimizers import *

# %% [markdown]
# ### Import CMAPSS Dataset

# %%
df = pd.read_csv("train_FD001.csv") #gamma = 0.9
df = df.drop(columns=["Unnamed: 0"])
df.head(5)
# Out:
#    machine  time         2         3         6         7         8         9  \
# 0        1     1 -0.315972 -1.372920 -1.721684 -0.134252 -0.925914 -0.999976
# 1        1     2  0.872701 -1.031695 -1.061754  0.211523 -0.643710 -0.999976
# 2        1     3 -1.961827  1.015652 -0.661797 -0.413156 -0.525940 -0.999976
# 3        1     4  0.324083 -0.008022 -0.661797 -1.261284 -0.784812 -0.999976
# 4        1     5 -0.864590 -0.690471 -0.621801 -1.251498 -0.301511 -0.999976
#
#         10        11  ...        16        17        18        19        20  \
# 0  0.14168  1.121113  ...  0.334254 -1.058865 -0.269065 -0.603801 -0.999976
# 1  0.14168  0.431920  ...  1.174871 -0.363637 -0.642829 -0.275845 -0.999976
# 2  0.14168  1.008131  ...  1.364688 -0.919819 -0.551616 -0.649128 -0.999976
# 3  0.14168  1.222798  ...  1.961255 -0.224592 -0.520163 -1.971617 -0.999976
# 4  0.14168  0.714376  ...  1.052846 -0.780774 -0.521736 -0.339837 -0.999976
#
#          21        24        25  reward        MC_Val
# 0 -0.781691  1.348460  1.194398       0 -1.821039e-07
# 1 -0.781691  1.016503  1.236892       0 -2.023377e-07
# 2 -2.073044  0.739873  0.503411       0 -2.248197e-07
# 3 -0.781691  0.352590  0.777773       0 -2.497996e-07
# 4 -0.136014  0.463242  1.059526       0 -2.775551e-07
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Import Predictron Model

# %%
#Neural network for Observation - Hidden State

class NN_OH(nn.Module):
    def __init__(self, input_size, out_size):
        super(NN_OH,self).__init__()
        self.fc1 = nn.Linear(input_size,32)
        self.fc2 = nn.Linear(32,16)
        self.fc3 = nn.Linear(16,out_size)
        
    def forward(self,x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return torch.nn.functional.softmax(x, dim=1)

# %%
#Neural network for Hidden State - Reward, Gamma, Lambda

class NN_reward(nn.Module):
    def __init__(self, input_size):
        super(NN_reward,self).__init__()
        self.fc1 = nn.Linear(input_size,32)
        self.fc2 = nn.Linear(32,16)
        self.fc3 = nn.Linear(16,3)
        
    def forward(self,x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
#Neural network for Hidden State - Value

class NN_val(nn.Module):
    def __init__(self, input_size):
        super(NN_val,self).__init__()
        self.fc1 = nn.Linear(input_size,32)
        self.fc2 = nn.Linear(32,16)
        self.fc3 = nn.Linear(16,1)
        
    def forward(self,x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
#Neural Network which will take my current hidden state to the next hidden state

class NN_HH(nn.Module):
    def __init__(self, input_size):
        super(NN_HH,self).__init__()
        self.fc1 = nn.Linear(input_size,32)
        self.fc2 = nn.Linear(32,16)
        self.fc3 = nn.Linear(16,input_size)
        
    def forward(self,x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return torch.nn.functional.softmax(x, dim=1)

# %%
#Now we have all the required neural networks for the predictron. Lets build the Predictron

class Predictronv4(nn.Module):
    def __init__(self, obs_size, hid_size, k=10):
        super(Predictronv4,self).__init__()
        
        #Instantiate Neural Network for Observation-Hidden State
        self.OH = NN_OH(obs_size, hid_size)
        
        #Instantiate Neural Network for Hidden State - Reward, Value
        self.HR = NN_reward(hid_size)
        
        #Instantiate Neural Network for Hidden State - Val
        self.HV = NN_val(hid_size)
        
        #Instantiate Neural Network for Hidden State - Next Hidden State
        self.HH = NN_HH(hid_size)
        
        #K-step return
        self.k = k
        
    def forward(self, x, isHidden=False):
        """
        
        isHidden - False is x is an observation vector
        
        """
        #First step: Get the Hidden state for the current observation
        if isHidden == False:
            x = self.OH(x)
        
        # Initialize lists
        rewards = []
        gammas = []
        lambdas = []
        values = []
        
        # forward pass
        for k in range(0, self.k + 1):

            rewards.append(self.HR(x)[:, 0].reshape(-1, 1))
            gammas.append(self.HR(x)[:, 1].reshape(-1, 1))
            lambdas.append(self.HR(x)[:, 2].reshape(-1, 1))
            values.append(self.HV(x))
            
            x = self.HH(x) #get the next hidden state

        # backwards pass to compute g-lambda
        gl = values[self.k]
        for k in range(0, self.k)[::-1]:
            gl = ((1 - lambdas[k])*values[k]) + (lambdas[k] * (rewards[k+1] + (gammas[k+1]*gl)))
        
        return gl.reshape(-1, 1)

# %%
def getXY(data):
    x = torch.tensor(data.iloc[:, 2:-2].values).float()
    y_target = torch.tensor(data.iloc[:,-1].values).float()
    y_target = y_target.reshape(-1,1)
    
    return x, y_target

# %%
x, y_target = getXY(df)

# %%
# Load Predictron with k=10
predictron = Predictronv4(x.shape[1], 4, 10)
predictron.load_state_dict(torch.load("training_FD001_k10.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### DQN

# %%
class Brain:
    def __init__(self, stateCnt, actionCnt):
        self.stateCnt = stateCnt
        self.actionCnt = actionCnt

        self.model = self._createModel()

    def _createModel(self):
        model = Sequential()
        model.add(keras.Input(shape=(self.stateCnt,)))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(self.actionCnt, activation='linear'))

        opt = RMSprop(lr=0.00025)
        model.compile(loss='mse', optimizer=opt)

        return model

    def train(self, x, y, verbose=0):
        """
        Performs a gradient descent step with given batch
        """
        self.model.fit(x, y, batch_size=x.shape[0], verbose=verbose)

    def predict(self, s):
        """
        Predicts the Q function values
        """
        if type(s) is torch.Tensor:
            s = s.detach().numpy()
        return self.model.predict(s)

    def predictOne(self, s):
        if type(s) is torch.Tensor:
            s = s.detach().numpy()
        return self.predict(s.reshape(1, self.stateCnt)).flatten()

# %%
class Environment:
    
    def __init__(self):
        return

    def step(self, s, a):
        """
        Given action a and current state s, 
        returns a new state, reward, done, invalid indicator
        
        """
        done = False
        invalid = False 
        
        # if the action is to repair, the next state is [1, 0, 0, 0]
        # otherwise, ask the predictron for the next state
        s_ = torch.tensor([1, 0, 0, 0]).float().reshape(-1, 4)
        if a == 0:
            s_ = predictron.HH(s).reshape(-1, 4)
            health_s = torch.argmax(s).item()
            health_s_ = torch.argmax(s_).item()

            # if the next state is invalid 
            if (health_s_ < health_s):
                invalid = True
            # if the next state's health is 3
            if (health_s_ == 3):
                done = True
                
        # compute reward
        reward = 0
        for state in range(1, 5):
            reward += (50 * (4 - state) * s[:, state - 1].item()) + (-50 * state * a)
        
        return s_, reward, done, invalid
    
    def run(self, agent, T, M):
        """
        T: timesteps per episode
        M: number of episodes
        """
        
        for e in range(0, M):
            
            s = torch.tensor([1, 0, 0, 0]).float().reshape(-1, 4)
            
            reward_accum = 0
        
            for t in range(0, T):           

                a = agent.act(s) #decide which action to take

                # environment performs this action and returns a new state and reward
                s_, r, done, invalid = self.step(s, a) 
                reward_accum += r

                # agent observes new sample and performs a learning step
                if invalid:
                    break
                agent.observe( (s, a, reward_accum, s_) ) 
                agent.replay()             

                s = s_

                if done:
                    break

# %%
class Memory:   # stored as ( s, a, r, s_ )

    def __init__(self, capacity):
        self.capacity = capacity
        self.samples = []

    def add(self, sample):
        """
        stores the experience into self.samples, 
        ensuring it doesn't exceed its capacity
        """
        self.samples.append(sample)        

        if len(self.samples) > self.capacity:
            self.samples.pop(0)

    def sample(self, n):
        """
        returns n random samples from memory
        """
        n = min(n, len(self.samples))
        return random.sample(self.samples, n)

# %%
MEMORY_CAPACITY = 100000
BATCH_SIZE = 64

GAMMA = 0.99

MAX_EPSILON = 1
MIN_EPSILON = 0.01
LAMBDA = 0.001      # speed of decay

class Agent:
    steps = 0
    epsilon = MAX_EPSILON

    def __init__(self, stateCnt, actionCnt):
        self.stateCnt = stateCnt
        self.actionCnt = actionCnt

        self.brain = Brain(stateCnt, actionCnt)
        self.memory = Memory(MEMORY_CAPACITY)
        
    def act(self, s):
        """
        With epsilon probability, chooses a random action, otherwise
        selects the best action with the current Q
        """
        if random.random() < self.epsilon:
            return random.randint(0, self.actionCnt-1)
        else:
            return np.argmax(self.brain.predictOne(s))

    def observe(self, sample):  # in (s, a, r, s_) format
        self.memory.add(sample)        

        # slowly decrease Epsilon based on our eperience
        self.steps += 1
        self.epsilon = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * math.exp(-LAMBDA * self.steps)

    def replay(self):    
        # fetch a batch of random samples from memory
        batch = self.memory.sample(BATCH_SIZE)
        batchLen = len(batch)

        no_state = np.zeros(self.stateCnt)

        states = np.array([ o[0].detach().numpy() for o in batch ])
        states_ = np.array([ o[3].detach().numpy() for o in batch ])
 
        p = self.brain.predict(states)
        p = [x[0] for x in p]
        p_ = self.brain.predict(states_)
        p_ = [x[0] for x in p_]

        x = np.zeros((batchLen, self.stateCnt))
        y = np.zeros((batchLen, self.actionCnt))
        
        for i in range(batchLen):
            o = batch[i]
            s = o[0]; a = o[1]; r = o[2]; s_ = o[3]

            t = p[i] #q value
            if torch.argmax(s_).item() == 3:
                t[a] = r
            else:
                t[a] = r + GAMMA * predictron.forward(s_, True)

            x[i] = s.detach().numpy()
            y[i] = t

        self.brain.train(x, y)

# %% [markdown]
# ### Integration of DQN and Predictron

# %%
loss_fn = nn.MSELoss()
optimizer = optim.Adam(predictron.parameters(), lr = 1e-3) 

stateCnt = 4
actionCnt = 2

agent = Agent(stateCnt, actionCnt)
env = Environment()

j = 3
l = 10

timesteps = 20
episodes = 5

initial_iter = True

while True:
    
    permutations = []
    q_values = []
    
    if initial_iter == False:
        
        # Check for convergence by randomly generating hidden states and
        # computing their values before the Q update
        for i in range(0, 20):
            
            lst = np.random.random(4)
            lst = lst / sum(lst)
            permutations.append(torch.tensor(lst).float().reshape(-1, 4))
            
            q_values.append(agent.brain.predict(torch.tensor(lst).float().reshape(-1, 4)))
            
            
    # Update Q using trained Predictron. Repeat j times
    for i in range(0, j):
        env.run(agent, timesteps, episodes)

    # Check for convergence
    if initial_iter == False:
        frobenius_norm_error = 0
        for i in range(0, 20):

            p = permutations[i]
            old_q = q_values[i][0]
            updated_q = agent.brain.predict(p)[0]

            frobenius_norm_error += sum((old_q - updated_q)**2)

        frobenius_norm_error = np.sqrt(frobenius_norm_error)
        print(frobenius_norm_error)
    

    # collect l trajectories using Q
    states = []
    q_values = []
    for i in range(0, l):
        curr = torch.tensor([1, 0, 0, 0]).float().reshape(-1, 4)
        done_ = False
        for t in range(0, timesteps):
            
            # get next action
            action = agent.act(curr)
            # get q-value of action
            q_value = agent.brain.predict(curr)[0][action]

            states.append(curr.detach().numpy())
            q_values.append(q_value)

            if done_:
                break
            
            # update curr to next state
            curr, r, done, invalid = env.step(curr, action)
            
            # if invalid == True, end episode
            if invalid == True:
                break
                
            # update done_
            done_ = done
            
    
    # Update the Predictron using new trajectories

    outputs = predictron.forward(torch.tensor(states).float().reshape(-1, 4), True)
    loss = loss_fn(outputs, torch.tensor(q_values).float().reshape(-1, 1))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if initial_iter == True:
        initial_iter = False
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1117 22:11:06.046887 4613811648 network.py:957] Model was constructed with shape (None, 4) for input Tensor("input_1:0", shape=(None, 4), dtype=float32), but it was called on an input with incompatible shape (None, 1, 4).
# W1117 22:11:07.856551 4613811648 def_function.py:598] 5 out of the last 5 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:08.178766 4613811648 def_function.py:598] 6 out of the last 6 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:08.504408 4613811648 def_function.py:598] 7 out of the last 7 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:08.838658 4613811648 def_function.py:598] 8 out of the last 8 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:09.345911 4613811648 def_function.py:598] 9 out of the last 9 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:09.949340 4613811648 def_function.py:598] 10 out of the last 10 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:10.334111 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:10.717010 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:11.167336 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:11.708981 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:12.096526 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:12.523731 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:12.913842 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:13.330305 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:13.743319 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:14.171354 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:14.600863 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:15.110576 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:15.663600 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:16.190880 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:16.765258 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:17.419119 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:18.096826 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:18.591994 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:19.101035 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:19.565443 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:20.390734 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:20.449794 4613811648 network.py:957] Model was constructed with shape (None, 4) for input Tensor("input_1:0", shape=(None, 4), dtype=float32), but it was called on an input with incompatible shape (32, 1, 4).
# W1117 22:11:21.123831 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:21.687489 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:22.352530 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:23.179255 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:23.718143 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:24.450654 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:25.507195 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:26.086061 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:26.874033 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:27.909367 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:28.710731 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:29.579180 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:30.501872 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:31.467470 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:32.414582 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:33.352719 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:34.194993 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:35.176175 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:36.091198 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:36.897234 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:37.699687 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:38.493740 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:39.328827 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:40.141486 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:40.994878 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:41.837479 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:42.687503 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:43.515086 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:44.367267 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:45.223455 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:46.119220 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:47.000527 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# W1117 22:11:48.067466 4613811648 def_function.py:598] 11 out of the last 11 calls to <function Model.make_train_function.<locals>.train_function at 0x7fc6fae6e9d8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# 7.810035442712688
# 11.474822274038907
# 14.85580297109672
